# %%
# 벅스 크롤링 https://music.bugs.co.kr/chart

# %%
pip install selenium  # selenium 설치

# %%
print(html.text)  # 읽어온 사이트의 내용(코드) 보기
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# 	<!-- bgsweb-www909 -->
# 	<meta charset="utf-8">
# 	<meta http-equiv="X-UA-Compatible" content="IE=edge">
# 	<meta name="keywords" content="음악,음악 스트리밍,최신음악,인기가요,뮤직비디오,앨범,플레이어,mp3 다운로드,놀면뭐하니,유플래쉬,유플래시" />
# 	<meta name="viewport" content="width=device-width, initial-scale=1" />
#
# <script type="text/javascript">
# 	if(!(location.href.indexOf("music.bugs.co.kr/newPlayer") >= 0 || location.href.indexOf("music.bugs.co.kr/newRadio") >= 0 || location.href.indexOf("localhost") >= 0))
# 		document.domain = 'bugs.co.kr';
#
# 	var g_urlBase = "https://www.bugs.co.kr";
# 	var g_urlWww = "https://www.bugs.co.kr";
# 	var g_urlSecure = "https://secure.bugs.co.kr";
# 	var g_urlMusic = "https://music.bugs.co.kr";
# 	var g_urlMusicSecure = "https://music.bugs.co.kr";
# 	var g_urlMember = "https://secure.bugs.co.kr/member";
# 	var g_urlFile = "https://file.bugsm.co.kr/wbugs";
# 	var g_urlFile_n ="https://file.bugsm.co.kr/nbugs";
# ...

# %%
soup = bs(html.text)

# %%
print(soup)

# %%
print(len(soup.select('tr')))

# %%
print(len(soup.select('tbody > tr')))

# %%
print(len(soup.select('table > tbody > tr')))

# %%
print(len(soup.select('table.byChart > tbody > tr')))

# %%
songs = soup.select('table.byChart > tbody > tr')
song = songs[0]
print(song)

# %%
# 노래 제목 추출
len(song.select('a'))

# %%
len(song.select('p > a'))

# %%
title = song.select('p.title > a')
print(title)

# %%
title = song.select('p.title > a')[0].text
print(title)

# %%
singer = song.select('p.artist > a')
print(singer)

# %%
singer = song.select('p.artist > a')[0].text
print(singer)

# %%
songs = soup.select('table.byChart > tbody > tr')
song = songs[2]
title = song.select('p.title > a')[0].text
print(title)
singer = song.select('p.artist > a')[0].text
print(singer)

# %%
# 순위 100 곡 추출
song_data = []
rank = 1

url = "https://music.bugs.co.kr/chart"
html = requests.get(url)
soup = bs(html.text)
songs = soup.select('table.byChart > tbody > tr')

for song in songs:
    title = song.select('p.title > a')[0].text
    singer = song.select('p.artist > a')[0].text
    song_data.append(['Bugs',rank, title, singer])
    rank += 1
print(song_data)

# %%
# 순위 100 곡 추출
song_data = []
rank = 1

url = "https://music.bugs.co.kr/chart"
html = requests.get(url)
soup = bs(html.text)
songs = soup.select('table.byChart > tbody > tr')

for i in range(100) :
    song = songs[i]
    title = song.select('p.title > a')[0].text
    singer = song.select('p.artist > a')[0].text
    song_data.append(['Bugs',rank, title, singer])
    
    print(f"벅스 차트  순위: {rank}, 곡명: {title}, 가수: {singer}")
    rank += 1

# %%
pip install pandas

# %%
pip install openpyxl

# %%
# 순위 100 곡 추출
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

song_data = []
rank = 1

url = "https://music.bugs.co.kr/chart"
html = requests.get(url)
soup = bs(html.text)
songs = soup.select('table.byChart > tbody > tr')

for song in songs:
    title = song.select('p.title > a')[0].text
    singer = song.select('p.artist > a')[0].text
    song_data.append(['Bugs',rank, title, singer])
    rank += 1

# 이중 리스트로 만든 100곡을 데이터프레임으로 전환하기
df = pd.DataFrame(song_data, columns = ['서비스', '순위', '노래제목', '가수명'])
df

# 데이터프레임을 엑셀로 젖장하기
df.to_excel('Bugs.xlsx', index = False)
